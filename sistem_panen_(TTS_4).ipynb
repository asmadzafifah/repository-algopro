# %% [markdown]
# <a href="https://colab.research.google.com/github/asmadzafifah/repository-algopro/blob/main/sistem_panen_(TTS_4).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# main.py
def hitung_total_panen(panen_pagi, panen_sore):
    return panen_pagi + panen_sore

if __name__ == "__main__":
    total = hitung_total_panen(120, 80)
    print(f"Total Hasil Panen: {total} kg")
# Out:
# Total Hasil Panen: 200 kg
